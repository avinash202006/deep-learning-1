# %% [markdown]
# <a href="https://colab.research.google.com/github/avinash202006/deep-learning-1/blob/main/student_details.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Student Details

name = "Rahul"
age = 20
marks = 85

print("Name:", name)
print("Age:", age)
print("Marks:", marks)
# Out:
# Name: Rahul
# Age: 20
# Marks: 85
