# %% [markdown]
# <a href="https://colab.research.google.com/github/avinash202006/deep-learning-1/blob/main/AVERAGE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Find average of numbers

numbers = [10, 20, 30, 40, 50]

average = sum(numbers) / len(numbers)

print("Average =", average)
# Out:
# Average = 30.0
