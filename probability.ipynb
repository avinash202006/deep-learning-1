# %% [markdown]
# <a href="https://colab.research.google.com/github/avinash202006/deep-learning-1/blob/main/probability.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Probability Example

favorable = 2
total = 6

probability = favorable / total

print("Probability =", probability)
# Out:
# Probability = 0.3333333333333333
