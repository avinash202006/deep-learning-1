# %% [markdown]
# <a href="https://colab.research.google.com/github/avinash202006/deep-learning-1/blob/main/Decode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split

# Load data
data = load_digits()
X = data.data / 16.0

# Encoder
input_layer = Input(shape=(64,))
encoded = Dense(32, activation='relu')(input_layer)
encoded = Dense(16, activation='relu')(encoded)

# Decoder
decoded = Dense(32, activation='relu')(encoded)
decoded = Dense(64, activation='sigmoid')(decoded)

# Autoencoder
autoencoder = Model(input_layer, decoded)

autoencoder.compile(optimizer='adam',
                    loss='mse')

autoencoder.fit(X, X,
                epochs=50,
                batch_size=32)

# Reconstruction
reconstructed = autoencoder.predict(X)

print("Original:")
print(X[0])

print("Reconstructed:")
print(reconstructed[0])
# Out:
# Epoch 1/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 0.1342
# Epoch 2/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0689
# Epoch 3/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0564
# Epoch 4/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0448
# Epoch 5/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0389
# Epoch 6/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0351
# Epoch 7/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0320
# Epoch 8/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0294
# Epoch 9/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0275
# Epoch 10/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0260
# Epoch 11/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0245
# Epoch 12/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0232
# Epoch 13/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0221
# Epoch 14/50
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0212
# Epoch 15/50
# ...
