# %% [markdown]
# <a href="https://colab.research.google.com/github/avinash202006/deep-learning-1/blob/main/RBM_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.neural_network import BernoulliRBM
import numpy as np

X = np.array([
    [1,0,1],
    [0,1,1],
    [1,1,0],
    [0,0,1]
])

rbm = BernoulliRBM(n_components=2)

rbm.fit(X)

print("RBM Model Trained Successfully")
